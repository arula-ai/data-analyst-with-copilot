# %% [markdown]
# # Sub-Lab A — Root Cause Analysis
# **Orion Payments Inc. — Platform Log Analysis**
#
# Use this notebook for Stage 1 profiling and Stage 3 visualization.
# All instructions are in `SUB_LAB_GUIDE.md`.
#
# **Dataset:** `../data/rca_app_logs.csv` — 300 synthetic application log entries
# **Reference:** `../data/rca_schema.md` — column definitions and valid ranges
# **Codebase:** `../data/app_service.py` — review this before analyzing the logs

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sqlite3
import os

# %matplotlib inline
print('Environment ready. Libraries loaded.')

# %%
# Load the dataset
df = pd.read_csv('../data/rca_app_logs.csv')
print(f'Dataset loaded: {df.shape[0]} rows, {df.shape[1]} columns')
df.head()

# %%
# Quick schema check
print('Column data types:')
print(df.dtypes)
print('\nNull counts per column:')
print(df.isnull().sum())
print('\nLog level distribution:')
print(df['log_level'].value_counts())

# %% [markdown]
# ## Your Analysis Starts Here
#
# Replace the cells below with Copilot-generated analysis.
#
# - **Pre-step:** Use the **Exploratory Data Analyst** agent to review `app_service.py` and form hypotheses
# - **Stage 1:** Use the **Data Profiling Analyst** agent to generate profiling code
# - **Stage 2:** Use the **Data Cleaning Engineer** agent for cleaning + SQL interrogation
# - **Stage 3:** Use the **Visualization Architect** agent for labeled charts
#
# Reference: `SUB_LAB_GUIDE.md` for stage-by-stage instructions
# Prompts: `../../reference/PROMPT_PATTERN.md` for RIFCC-DA template

# %%
# Stage 1 — Log Profiling
# Use Copilot with the Data Profiling Analyst agent
# Key outputs: row count, log_level distribution, ERROR/FATAL by service, null counts
# Do NOT modify the dataframe in this stage — profiling is read-only

# %%
# Stage 2 — SQL Interrogation
# Use Copilot with the Data Cleaning Engineer agent
# Load cleaned CSV into in-memory SQLite and run error pattern queries
# sqlite3 is standard library — no additional install required

# %%
# Stage 3 — Visualizations
# Use Copilot with the Visualization Architect agent
# Required charts:
#   1. ERROR + FATAL count by service_name (horizontal bar)
#   2. response_time_ms distribution for top failing service (histogram)
#   3. ERROR and FATAL count over time by hour (line chart)
# Rules: label all axes, no user_id_masked in charts, Y-axis starts at 0
